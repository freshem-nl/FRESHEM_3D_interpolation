# %%
import pandas as pd

# %%
path=r"C:\WERK\DATA\FRESHEM\NextCloud\Team4-Chloride\test_data\inversions\zeeland_noord\ZLN_p001-002_nmc500_chloride.feather"

# %%
df = pd.read_feather(path)

# %%
df
# Out:
#                 x          y       top    bottom  line_no        cl_p1  \
# 0        34636.80  399726.98    0.0000   -0.5000   100101     0.000000
# 1        34636.80  399726.98   -0.5000   -1.0871   100101     0.000000
# 2        34636.80  399726.98   -1.0871   -1.7766   100101  1055.677028
# 3        34636.80  399726.98   -1.7766   -2.5863   100101     0.000000
# 4        34636.80  399726.98   -2.5863   -3.5371   100101     0.000000
# ...           ...        ...       ...       ...      ...          ...
# 1678855  41300.92  395863.63 -156.1000 -183.8600   922109          NaN
# 1678856  41300.92  395863.63 -183.8600 -216.4600   922109          NaN
# 1678857  41300.92  395863.63 -216.4600 -254.7400   922109          NaN
# 1678858  41300.92  395863.63 -254.7400 -299.6900   922109          NaN
# 1678859  41300.92  395863.63 -299.6900 -449.6850   922109          NaN
#
#                cl_p2        cl_p5      cl_p10       cl_p15  ...       cl_p60  \
# ...
